# %% [raw]
# ---
# title: "Mirror 镜子 0000-01-01"
# description: "想象力是价值的源泉，现实是行动者的酬劳"
# author: "AndyBourne"
# date: "0000-01-01"
# categories: [Mirror, 镜子, 创作]
# image: "cover.jpg" # 放在同级目录下的封面图
# number-sections: 1
# draft: false       # 如果设为 true，文章将不会被发布
# ---

# %% [markdown]
# # 第一原则
# * 存在平行时空
#
# # 第二原则
# * 超能力者可以穿越平行时空，但是不能改变不在同一维度的时空，即只能观察低纬度时空，每次只能观察一个，观察的同时要消耗的自己的物理尺度即生命值
#
# # 第三原则
# * 在一个封闭的平时时空里，一个人的生命如果能跨越其物理尺度，那么他就能跃迁到另一个平行时空（且维度只能比此前高一个等级里)。
#
# # 第四原则
# * 最后一个假设，平行时空最高等级与最低等级的维度之差不能大于等于10个等级.
